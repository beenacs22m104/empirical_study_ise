# %%
from create_tables import *
pd.set_option('display.max_rows', 500)

# %%
dataset_sizes()
# Out:
#                                    Questions Non-duplicates      Duplicates  \
# Source         Topic
# Stack Exchange Game development     54,684.0       53,514.0  1,170.0 (2.1%)
# Stack Overflow Game development        906.0          899.0      7.0 (0.8%)
#                General development  27,795.0       27,194.4    600.6 (2.2%)
#
#                                       Pairs
# Source         Topic
# Stack Exchange Game development     1,222.0
# Stack Overflow Game development         7.0
#                General development    614.0

# %%
dup_pair_similarity_summary()
# Out:
#                                                                   (1)  \
# Dataset                       Score          Similarity
# Game Dev. Stack Exchange      recall-rate@5  Jaccard           14.96
#                                              TF-IDF            17.86
#                                              BM25              16.92
#                                              Topic              1.71
#                                              Doc2Vec            0.00
#                               recall-rate@10 Jaccard           19.23
#                                              TF-IDF            21.37
#                                              BM25              21.28
#                                              Topic              2.48
#                                              Doc2Vec            0.00
#                               recall-rate@20 Jaccard           24.27
#                                              TF-IDF            26.15
#                                              BM25              26.67
#                                              Topic              3.93
#                                              Doc2Vec            0.09
# Stack Overflow (Game dev.)    recall-rate@5  Jaccard           42.86
#                                              TF-IDF            71.43
#                                              BM25              57.14
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@10 Jaccard           57.14
#                                              TF-IDF            71.43
#                                              BM25              71.43
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@20 Jaccard           57.14
#                                              TF-IDF            85.71
#                                              BM25              71.43
#                                              Topic              0.00
#                                              Doc2Vec            0.00
# Stack Overflow (General dev.) recall-rate@5  Jaccard     18.01 (0.63)
#                                              TF-IDF      20.12 (1.24)
#                                              BM25        20.11 (0.53)
#                                              Topic        1.53 (0.43)
#                                              Doc2Vec      0.03 (0.08)
#                               recall-rate@10 Jaccard     23.18 (0.60)
#                                              TF-IDF      25.28 (1.48)
#                                              BM25        25.71 (1.19)
#                                              Topic        2.03 (0.69)
#                                              Doc2Vec      0.07 (0.15)
#                               recall-rate@20 Jaccard     28.81 (0.78)
#                                              TF-IDF      31.94 (1.17)
#                                              BM25        30.47 (0.63)
#                                              Topic        3.07 (0.59)
#                                              Doc2Vec      0.07 (0.15)
#
#                                                                   (2)  \
# Dataset                       Score          Similarity
# Game Dev. Stack Exchange      recall-rate@5  Jaccard           10.85
#                                              TF-IDF            16.75
#                                              BM25              11.79
#                                              Topic              2.31
#                                              Doc2Vec            0.60
#                               recall-rate@10 Jaccard           13.42
#                                              TF-IDF            21.88
#                                              BM25              15.04
#                                              Topic              2.99
#                                              Doc2Vec            1.11
#                               recall-rate@20 Jaccard           16.75
#                                              TF-IDF            27.44
#                                              BM25              19.57
#                                              Topic              4.79
#                                              Doc2Vec            1.54
# Stack Overflow (Game dev.)    recall-rate@5  Jaccard           28.57
#                                              TF-IDF            57.14
#                                              BM25              28.57
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@10 Jaccard           42.86
#                                              TF-IDF            57.14
#                                              BM25              42.86
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@20 Jaccard           57.14
#                                              TF-IDF            71.43
#                                              BM25              71.43
#                                              Topic              0.00
#                                              Doc2Vec            0.00
# Stack Overflow (General dev.) recall-rate@5  Jaccard     12.85 (0.77)
#                                              TF-IDF      21.21 (1.50)
#                                              BM25        14.65 (0.76)
#                                              Topic        2.86 (0.69)
#                                              Doc2Vec      0.67 (0.42)
#                               recall-rate@10 Jaccard     16.02 (0.57)
#                                              TF-IDF      27.14 (1.60)
#                                              BM25        19.61 (0.88)
#                                              Topic        4.46 (0.25)
#                                              Doc2Vec      1.16 (0.66)
#                               recall-rate@20 Jaccard     20.65 (0.72)
#                                              TF-IDF      33.03 (0.91)
#                                              BM25        23.94 (0.64)
#                                              Topic        6.19 (0.66)
#                                              Doc2Vec      1.70 (0.66)
#
#                                                                   (3)  \
# Dataset                       Score          Similarity
# Game Dev. Stack Exchange      recall-rate@5  Jaccard            4.36
#                                              TF-IDF             5.64
#                                              BM25               6.32
#                                              Topic              2.65
#                                              Doc2Vec            0.00
#                               recall-rate@10 Jaccard            7.44
#                                              TF-IDF             9.06
#                                              BM25               9.32
#                                              Topic              3.50
#                                              Doc2Vec            0.00
#                               recall-rate@20 Jaccard           10.77
#                                              TF-IDF            12.74
#                                              BM25              13.68
#                                              Topic              5.04
#                                              Doc2Vec            0.09
# Stack Overflow (Game dev.)    recall-rate@5  Jaccard           14.29
#                                              TF-IDF            28.57
#                                              BM25              14.29
#                                              Topic             14.29
#                                              Doc2Vec            0.00
#                               recall-rate@10 Jaccard           42.86
#                                              TF-IDF            42.86
#                                              BM25              42.86
#                                              Topic             14.29
#                                              Doc2Vec            0.00
#                               recall-rate@20 Jaccard           42.86
#                                              TF-IDF            42.86
#                                              BM25              42.86
#                                              Topic             14.29
#                                              Doc2Vec            0.00
# Stack Overflow (General dev.) recall-rate@5  Jaccard      6.66 (1.03)
#                                              TF-IDF       8.39 (0.44)
#                                              BM25         9.29 (0.86)
#                                              Topic        2.50 (0.63)
#                                              Doc2Vec      0.03 (0.08)
#                               recall-rate@10 Jaccard     10.06 (1.08)
#                                              TF-IDF      11.92 (0.24)
#                                              BM25        13.26 (0.69)
#                                              Topic        3.23 (0.38)
#                                              Doc2Vec      0.07 (0.15)
#                               recall-rate@20 Jaccard     14.75 (0.61)
#                                              TF-IDF      17.25 (0.46)
#                                              BM25        17.68 (0.87)
#                                              Topic        5.26 (0.89)
#                                              Doc2Vec      0.07 (0.15)
#
#                                                                   (4)  \
# Dataset                       Score          Similarity
# Game Dev. Stack Exchange      recall-rate@5  Jaccard           14.53
#                                              TF-IDF            24.53
#                                              BM25              14.96
#                                              Topic              3.42
#                                              Doc2Vec            1.28
#                               recall-rate@10 Jaccard           17.86
#                                              TF-IDF            30.34
#                                              BM25              19.40
#                                              Topic              4.44
#                                              Doc2Vec            1.71
#                               recall-rate@20 Jaccard           21.97
#                                              TF-IDF            36.92
#                                              BM25              26.15
#                                              Topic              6.75
#                                              Doc2Vec            2.56
# Stack Overflow (Game dev.)    recall-rate@5  Jaccard           28.57
#                                              TF-IDF            57.14
#                                              BM25              57.14
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@10 Jaccard           42.86
#                                              TF-IDF            85.71
#                                              BM25              57.14
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@20 Jaccard           71.43
#                                              TF-IDF            85.71
#                                              BM25              85.71
#                                              Topic              0.00
#                                              Doc2Vec            0.00
# Stack Overflow (General dev.) recall-rate@5  Jaccard     17.35 (0.80)
#                                              TF-IDF      29.27 (1.45)
#                                              BM25        18.88 (1.10)
#                                              Topic        3.30 (0.50)
#                                              Doc2Vec      0.90 (0.28)
#                               recall-rate@10 Jaccard     21.48 (1.35)
#                                              TF-IDF      36.16 (1.15)
#                                              BM25        25.41 (1.26)
#                                              Topic        4.46 (0.51)
#                                              Doc2Vec      1.73 (0.19)
#                               recall-rate@20 Jaccard     27.14 (1.15)
#                                              TF-IDF      45.46 (0.96)
#                                              BM25        30.50 (0.63)
#                                              Topic        7.39 (0.85)
#                                              Doc2Vec      2.80 (0.54)
#
#                                                                   (5)  \
# Dataset                       Score          Similarity
# Game Dev. Stack Exchange      recall-rate@5  Jaccard           15.90
#                                              TF-IDF            26.24
#                                              BM25              16.84
#                                              Topic              3.76
#                                              Doc2Vec            1.20
#                               recall-rate@10 Jaccard           19.66
#                                              TF-IDF            32.82
#                                              BM25              21.37
#                                              Topic              5.30
#                                              Doc2Vec            2.14
#                               recall-rate@20 Jaccard           24.70
#                                              TF-IDF            41.03
#                                              BM25              28.38
#                                              Topic              7.69
#                                              Doc2Vec            2.99
# Stack Overflow (Game dev.)    recall-rate@5  Jaccard           28.57
#                                              TF-IDF            71.43
#                                              BM25              57.14
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@10 Jaccard           28.57
#                                              TF-IDF            85.71
#                                              BM25              57.14
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@20 Jaccard           42.86
#                                              TF-IDF            85.71
#                                              BM25              85.71
#                                              Topic             42.86
#                                              Doc2Vec            0.00
# Stack Overflow (General dev.) recall-rate@5  Jaccard     19.21 (0.96)
#                                              TF-IDF      31.90 (1.10)
#                                              BM25        21.48 (0.76)
#                                              Topic        4.56 (0.90)
#                                              Doc2Vec      1.37 (0.38)
#                               recall-rate@10 Jaccard     24.21 (0.50)
#                                              TF-IDF      39.56 (0.81)
#                                              BM25        28.07 (1.01)
#                                              Topic        6.60 (1.05)
#                                              Doc2Vec      2.03 (0.29)
#                               recall-rate@20 Jaccard     29.97 (0.44)
#                                              TF-IDF      47.52 (1.03)
#                                              BM25        34.73 (0.98)
#                                              Topic        9.29 (1.22)
#                                              Doc2Vec      2.96 (0.39)
#
#                                                                   (6)
# Dataset                       Score          Similarity
# Game Dev. Stack Exchange      recall-rate@5  Jaccard           14.44
#                                              TF-IDF            26.92
#                                              BM25              19.91
#                                              Topic              3.33
#                                              Doc2Vec            1.37
#                               recall-rate@10 Jaccard           20.17
#                                              TF-IDF            33.33
#                                              BM25              25.64
#                                              Topic              5.38
#                                              Doc2Vec            2.05
#                               recall-rate@20 Jaccard           24.19
#                                              TF-IDF            41.62
#                                              BM25              34.19
#                                              Topic              8.29
#                                              Doc2Vec            3.08
# Stack Overflow (Game dev.)    recall-rate@5  Jaccard           42.86
#                                              TF-IDF            71.43
#                                              BM25              71.43
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@10 Jaccard           71.43
#                                              TF-IDF            71.43
#                                              BM25              71.43
#                                              Topic              0.00
#                                              Doc2Vec            0.00
#                               recall-rate@20 Jaccard           71.43
#                                              TF-IDF            71.43
#                                              BM25              85.71
#                                              Topic              0.00
#                                              Doc2Vec            0.00
# Stack Overflow (General dev.) recall-rate@5  Jaccard     19.22 (0.85)
#                                              TF-IDF      31.70 (1.33)
#                                              BM25        25.54 (1.45)
#                                              Topic        4.23 (0.60)
#                                              Doc2Vec      2.07 (0.27)
#                               recall-rate@10 Jaccard     23.85 (1.32)
#                                              TF-IDF      40.09 (1.21)
#                                              BM25        32.97 (0.87)
#                                              Topic        6.66 (0.48)
#                                              Doc2Vec      3.43 (0.40)
#                               recall-rate@20 Jaccard     28.84 (1.04)
#                                              TF-IDF      48.85 (0.47)
#                                              BM25        41.09 (1.04)
#                                              Topic       10.16 (0.89)
#                                              Doc2Vec      5.16 (0.62)

# %%
candidate_evaluation_summary()
# Out:
#                                           Recall-rate@                \
#                                                      5            10
# dataset                       candidates
# Game Dev. Stack Exchange      1500              34.19         42.74
# Stack Overflow (Game dev.)    1500               0.00          0.00
# Stack Overflow (General dev.) 1500        38.83 (6.14)  48.67 (5.85)
#
#
#                                                     20
# dataset                       candidates
# Game Dev. Stack Exchange      1500              50.43
# Stack Overflow (Game dev.)    1500               0.00
# Stack Overflow (General dev.) 1500        58.33 (3.34)

# %%
print(cross_dataset_summary().to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
#                               &                               & \multicolumn{3}{l}{Recall-rate@} \\
#                               &                               &             5 &             10 &             20 \\
# dataset\_train & dataset\_test &               &                &                \\
# \midrule
# Game Dev. Stack Exchange & Game Dev. Stack Exchange &        34.19  &         42.74  &         50.43  \\
# Stack Overflow (Game dev.) & Game Dev. Stack Exchange &        25.21  &         34.19  &         42.31  \\
# Stack Overflow (General dev.) & Game Dev. Stack Exchange &  36.49 (0.89) &   43.85 (1.62) &   53.59 (0.49) \\
# Game Dev. Stack Exchange & Stack Overflow (Game dev.) &         0.00  &          0.00  &          0.00  \\
# Stack Overflow (Game dev.) & Stack Overflow (Game dev.) &         0.00  &          0.00  &          0.00  \\
# Stack Overflow (General dev.) & Stack Overflow (Game dev.) &   0.00 (0.00) &  20.00 (44.72) &  100.00 (0.00) \\
# Game Dev. Stack Exchange & Stack Overflow (General dev.) &  45.50 (7.77) &   54.00 (7.53) &   62.67 (5.88) \\
# Stack Overflow (Game dev.) & Stack Overflow (General dev.) &  34.83 (5.70) &   44.17 (5.68) &   55.83 (4.93) \\
# Stack Overflow (General dev.) & Stack Overflow (General dev.) &  43.40 (6.92) &   52.33 (5.91) &   61.23 (4.74) \\
# \bottomrule
# \end{tabular}

# %%
misclassified_summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11727/3953573280.py in <module>
# ----> 1 misclassified_summary()
#
# ~/done-21-arthur-duplicate_gamedev_questions-code/code/notebooks/create_tables.py in misclassified_summary()
#     229         n_misclassified = len(missed)
#     230         no_candidate = len(missed[~missed.has_dup])
# --> 231         top_ranked_dup = len(missed[missed.top_ranked_is_dup])
#     232         main_more_general = len(missed[missed.main_more_generic])
#     233
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'top_ranked_is_dup'
